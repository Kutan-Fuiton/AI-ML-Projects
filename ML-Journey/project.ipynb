# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

data = pd.read_csv('data/student.csv')

X = data[['Hours']]
y = data['Score']

model = LinearRegression()
model.fit(X,y)

predicted_score = model.predict(X)

# evaluate
mae = mean_absolute_error(y, predicted_score)
mse = mean_squared_error(y, predicted_score)
rmse = np.sqrt(mse)

# show results
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)


hour = float(input("Enter study hours: "))
new_pred = model.predict([[hour]])
print(f"Predicted Score for studying {hour} hours: {new_pred[0]}")
# Out:
# Mean Absolute Error (MAE): 0.6666666666666643
# Mean Squared Error (MSE): 0.6285714285714282
# Root Mean Squared Error (RMSE): 0.7928249671720916
# Predicted Score for studying 7.0 hours: 86.4
# c:\Users\Subarno Chakraborty\Coding\Python\AI-ML\AI-ML-Projects\ML-Journey\env\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
